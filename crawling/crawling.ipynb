# %%
import sys 
import os  
import re
import requests
import pandas as pd 
import numpy as np    
from bs4 import BeautifulSoup     
from selenium import webdriver   
from selenium.webdriver.common.keys import Keys
import chromedriver_autoinstaller

import time 
from tqdm import tqdm_notebook 

import warnings
warnings.filterwarnings('ignore')

# %%
import chromedriver_autoinstaller
chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)

# 대분류
driver.get('https://www.lotteon.com/search/render/render.ecn?render=nqapi&platform=pc&collection_id=9&u9=navigate&u8=FC01000000&login=Y&mallId=1')
time.sleep(2)

# %%
product = driver.find_elements_by_css_selector(' .srchFilterAccordionPanel .srchFilterOptions')
for i in range(0, len(product)):
    print(product[i].text)
# Out:
# 과일
# 채소
# 쌀/잡곡/견과
# 수산/건어물
# 정육/계란
# 우유/유제품
# 냉장/냉동/간편식
# 김치/반찬
# 생수/음료/주류
# 커피/원두/차
# 과자/디저트/아이스크림
# 면류/통조림
# 소스/오일/장류
# 건강/다이어트식품

# %%
product = driver.find_elements_by_css_selector(' .srchFilterAccordionPanel .srchFilterOptions')
product_list = str(product[0].text).split('\n')[:]
product_list = pd.DataFrame(product_list)
product_list.columns = ['대분류']
product_list
# Out:
#              대분류
# 0             과일
# 1             채소
# 2        쌀/잡곡/견과
# 3         수산/건어물
# 4          정육/계란
# 5         우유/유제품
# 6      냉장/냉동/간편식
# 7          김치/반찬
# 8       생수/음료/주류
# 9        커피/원두/차
# 10  과자/디저트/아이스크림
# 11        면류/통조림
# 12      소스/오일/장류
# 13     건강/다이어트식품

# %% [markdown]
# ## 하나하나씩 만드는 방법으로 하기로 함

# %% [markdown]
# ### 과일

# %%
fruit = []
driver.find_element_by_xpath(f'//*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/ul/li[1]/a/span').click()
fruit_cate = driver.find_elements_by_css_selector(' .srchFilterAccordionPanel .srchFilterOptions')

# %%
fruit_cate[0].text
fruit_list = str(fruit_cate[0].text).split('\n')[:]
fruit_list = pd.DataFrame(fruit_list)
fruit_list.columns = ['중분류']
fruit_list
# Out:
#           중분류
# 0        사과/배
# 1      감귤/한라봉
# 2      딸기/베리류
# 3    바나나/파인애플
# 4     망고/열대과일
# 5    수박/참외/메론
# 6    아보카도/무화과
# 7   오렌지/자몽/레몬
# 8    키위/매실/살구
# 9         토마토
# 10  포도/복숭아/자두
# 11       감/홍시
# 12        건과일
# 13     과일선물세트
# 14       냉동과일
# 15       기타과일

# %%
driver.find_element_by_xpath('//*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/ul/li[1]/a/span').click()

# %%
apple = []

for f in range(1,36):
    if f == 1:
        name = driver.find_elements_by_class_name('srchProductUnitTitle')
        time.sleep(2)
        for named in range(0,len(name)):
            apple.append(name[named].text)
        driver.find_element_by_xpath('//*[@id="c9_navigate1"]/div/a[7]').click()
    else:
        time.sleep(2)
        name = driver.find_elements_by_class_name('srchProductUnitTitle')
        time.sleep(2)
        for named in range(0,len(name)):
            apple.append(name[named].text)
        driver.find_element_by_xpath('//*[@id="c9_navigate1"]/div/a[8]').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# c:\Users\wkddn\OneDrive\문서\GitHub\Store_Analysis\crawling\crawling.ipynb 셀 10 in <cell line: 3>()
#      <a href='vscode-notebook-cell:/c%3A/Users/wkddn/OneDrive/%EB%AC%B8%EC%84%9C/GitHub/Store_Analysis/crawling/crawling.ipynb#X31sZmlsZQ%3D%3D?line=13'>14</a> for named in range(0,len(name)):
#      <a href='vscode-notebook-cell:/c%3A/Users/wkddn/OneDrive/%EB%AC%B8%EC%84%9C/GitHub/Store_Analysis/crawling/crawling.ipynb#X31sZmlsZQ%3D%3D?line=14'>15</a>     apple.append(name[named].text)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/wkddn/OneDrive/%EB%AC%B8%EC%84%9C/GitHub/Store_Analysis/crawling/crawling.ipynb#X31sZmlsZQ%3D%3D?line=15'>16</a> driver.find_element_by_xpath('//*[@id="c9_navigate1"]/div/a[8]').click()
#
# File c:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:514, in WebDriver.find_element_by_xpath(self, xpath)
#     492 """
#     493 Finds an element by xpath.
#     494
#    (...)
#     507         element = driver.find_element_by_xpath('//div/td[1]')
#     508 """
#     509 warnings.warn(
#     510     "find_element_by_* commands are deprecated. Please use find_element() instead",
#     511     DeprecationWarning,
#     512     stacklevel=2,
#     513 )
# --> 514 return self.find_element(by=By.XPATH, value=xpath)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:1238, in WebDriver.find_element(self, by, value)
#    1235     by = By.CSS_SELECTOR
#    1236     value = '[name="%s"]' % value
# -> 1238 return self.execute(Command.FIND_ELEMENT, {
#    1239     'using': by,
#    1240     'value': value})['value']
#
# File c:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:418, in WebDriver.execute(self, driver_command, params)
#     416 response = self.command_executor.execute(driver_command, params)
#     417 if response:
# --> 418     self.error_handler.check_response(response)
#     419     response['value'] = self._unwrap_value(
#     420         response.get('value', None))
#     421     return response
#
# File c:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="c9_navigate1"]/div/a[8]"}
#   (Session info: chrome=106.0.5249.91)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00CF1353+2233171]
# 	Ordinal0 [0x00C88E31+1805873]
# 	Ordinal0 [0x00B966FD+812797]
# 	Ordinal0 [0x00BC55DF+1005023]
# 	Ordinal0 [0x00BC57CB+1005515]
# 	Ordinal0 [0x00BF7632+1209906]
# 	Ordinal0 [0x00BE1AD4+1120980]
# 	Ordinal0 [0x00BF59E2+1202658]
# 	Ordinal0 [0x00BE18A6+1120422]
# 	Ordinal0 [0x00BBA73D+960317]
# 	Ordinal0 [0x00BBB71F+964383]
# 	GetHandleVerifier [0x00F9A2C2+2728322]
# 	GetHandleVerifier [0x00F8C184+2670660]
# 	GetHandleVerifier [0x00D8102A+528106]
# 	GetHandleVerifier [0x00D7FE10+523472]
# 	Ordinal0 [0x00C9028C+1835660]
# 	Ordinal0 [0x00C94758+1853272]
# 	Ordinal0 [0x00C94845+1853509]
# 	Ordinal0 [0x00C9E7E4+1894372]
# 	BaseThreadInitThunk [0x76B76739+25]
# 	RtlGetFullPathName_UEx [0x77CA8FD2+1218]
# 	RtlGetFullPathName_UEx [0x77CA8F9D+1165]

# %%
(apple)
# Out:
# ['충주 GAP 상생사과 (2.5KG/봉)',
#  '22년 산지직송 햇 나주배 가정용/가정용특품 3kg 5kg 15kg',
#  '홍로 사과 (4-7입/봉)',
#  '황금빛 김천 황옥 사과 (1.3KG/봉)',
#  '상생 배 (3KG/박스)',
#  '[GAP인증] 22년 고당도 햇 나주배 가정용/특품 3kg 5kg 15kg 나주직송 꼼꼼선별배송',
#  '정품 홍옥 사과 2kg내외',
#  '작아도 맛있는 밀양얼음골 사과 (6-10입/봉)',
#  '[2022햇사과] 산지애 씻어나온 꿀사과 3kg 2box (대과)',
#  '아리수 사과 (4-7입/봉)',
#  '세척사과 10kg 33-50과',
#  '문경사과 감홍사과 꿀 햇 산지직송사과 5kg 10kg',
#  '맘사과 가정용 사과 10Kg 대과(20~27과)',
#  '아삭아삭 시원한 달콤 당도선별 정품 햇배 중과 10kg',
#  '당도선별 아삭아삭 빨간 홍로사과 가정용 중과 5kg',
#  '22년산 햇배 나주 신고배 3kg 5kg 산지직송',
#  '세척사과 실중량 3kg+3kg(20~30과)',
#  '[산지직송] 정성들여 키운 달콤한 나주 신고배 5kg (9-10과)',
#  '꿀 홍로 햇사과 5kg 10kg 껍질째먹는 고당도 게르마늄 사과',
#  '[제] 사과 4-8입/봉 (슈퍼)',
#  '22년 울산 서생배 신고배 정품배 5kg 7.5kg 10kg 15kg',
#  '영천 루비에스 미니사과 (10-16입/팩)',
#  '황금 사과 시나노골드 노란 못난이 3kg 5kg 청송 산지직송 가정용',
#  '농가돕기사과(5~11입/봉)',
#  '세척사과 실중량 3kg+3kg+3kg(30~45과)',
#  '맘사과 가정용 사과 5Kg 대과(10~13과)',
#  '나씨네 문경 감홍 사과 3 4 5 10 kg 제철 과일 선물 사과 1021662',
#  '[정품] 꿀담은 햇 시나노골드 사과 3kg / 4kg 옵션 선택',
#  '[사전예약 10/12(수) 순차출고] 문경 고당도 감홍사과 3kg 10과내',
#  '사과 세척사과 3kg+3kg(20-30과)',
#  '[햇살가득] 경북 가정용 햇 사과 3.5kg (20~24과)',
#  '[베리세상] 국내산 대추사과 1kg (대)',
#  '아삭달콤 꿀 사과 4kg / 2개 주문시 10kg발송',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 9kg 소과 (50-65과)',
#  '[싱싱유통]2022수확 가정용 홍로 사과 7kg 중대과',
#  '[산지직송] 의성 황금사과(시나노골드) 중 4kg',
#  '경북 의성 햇 홍옥 사과 GAP 경북사과 5kg',
#  '열매나무 못난이 사과 3kgX3박스',
#  '세척사과 3kg+3kg+3kg(30-45과)',
#  '[대한농산] 정품 홍옥 사과 2kg내외(12과내외)',
#  '[착한식탁] 바른 가정용 세척사과 실중량 2.5kg 13-18과',
#  '맘사과 가정용 사과 10Kg 갈아먹는사과',
#  '경북 홍로 사과 가정용 5kg 29-33과',
#  '[방씨아들]경북 부사사과 고당도 꿀사과 3kg',
#  '사과 햇 홍로 청송 껍질째먹는 가을 꿀 사과 5kg',
#  '달빛사과 양광 세척사과 꿀사과 햇사과 4.5kg 21~23과',
#  '[2022햇사과] 산지애 알뜰 못난이사과(소과) 4.5kg 2box',
#  '[산지애] [빠른배송]NFC 사과즙 사과주스 사과원액 사과 120ml 60팩',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 9kg 대과 (29과내)',
#  '달빛사과 양광 세척사과 꿀사과 햇사과 3kg 10~13과',
#  '껍질째먹는 세척사과 5kg (23과내)',
#  '한입 꼬마사과 5kg 27~33과 (가정용)',
#  '시나노골드 가정용 대과 5kg 10-12과 황금사과',
#  '맘사과 가정용 사과 10Kg 대중과(28~33과)',
#  '[싱싱유통]홍로 세척사과 실중량 2.5kg (13-18과 내외) 꼬마소과',
#  '옥이네청과 주스용 사과 10kg 가정용 못난이 기스 흠과 (부자재포함중량)',
#  '[대한농산] 정품 홍옥 사과 2kg내외(8과내외)',
#  '[싱싱유통]세척 아오리사과 5kg 꼬마소과 18-28과내외',
#  '달아달아 시나노 스위트 사과 4.5kg(13-15과) 1박스',
#  '[AKmall][식품][방씨아들]꿀 경북 청송 햇 사과 부사사과 못난이사과(',
#  '나주 신고배 선물세트 7.5kg (11~13과)',
#  '경북산 햇 홍옥사과 1kg 5~6과내외',
#  '당도선별 아삭아삭 빨간 홍로사과 가정용 대과 10kg',
#  '[산지직송] 의성 황금사과(시나노골드) 중 2kg',
#  '맘사과 가정용 사과 5Kg 대중과(14~16과)',
#  '맛있는 사과 가정용 흠과 8kg(45과내)',
#  '경북 햇 정품 감홍사과 2kg 8~10과내외',
#  '[착한식탁] 가정용 아오리사과 10kg 꼬마소과 40-60과내외',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 9kg 중과(30-39과)',
#  'GAP배 2입/봉',
#  '[싱싱유통]2022수확 가정용 홍로 사과 9kg 중대과',
#  '당도선별 아삭아삭 빨간 홍로사과 가정용 소과 5kg',
#  '[산지직송] 의성 황금사과(시나노골드) 소 4kg',
#  '첫 수확 홍로 햇 한입사과 4.5kg',
#  '[싱싱유통]홍로 세척사과 실중량 2.5kg (12-14과 내외) 소과',
#  '한입 꼬마사과 8kg 40~56과 (가정용)',
#  '나주농협 신고배 5kg 8과 내외 22년 햇배',
#  '농가의맥)홍로사과3KG/박스',
#  '경북 정품 빨간사과 2kg 4kg',
#  '[착한식탁] 껍질채먹는 햇 홍로 세척 사과 꼬마소과 2.5kg(13-18과)',
#  '경북 안동 청송사과 시나노골드 노란 황금사과 꿀사과 쥬스용 10KG',
#  '사과 특대과 10kg(27-32과)',
#  '맘사과 감홍,시나노골드 황금사과,시나노스위트 못난이 꿀사과 3kg,5kg',
#  '당도선별 아삭아삭 빨간 홍로사과 가정용 대과 5kg',
#  '[2022햇사과] 산지애 알뜰 못난이사과(중과) 4.5kg 1box',
#  '나주배 꿀배 가정용 선물용 3kg 5kg 15kg',
#  '맘사과 가정용 사과 5Kg 중소과(17~20과)',
#  '[2022햇사과] 산지애 씻어나온 꿀사과 3kg 1box (대과)',
#  '[2022햇사과] 산지애 알뜰 못난이사과(대과) 4kg 2box',
#  '[2022햇사과] 산지애 알뜰 못난이사과(대과) 4kg 1box',
#  '[이슬마루] 황금사과 시나노골드 흠과 3kg(10~13과)',
#  '[베리세상] 국내산 대추사과 2kg (대)',
#  '[웰굿] 경북직송 가정용 감홍 사과 5kg(18-19과,중과)',
#  '맘사과 가정용 사과 10Kg 중소과(34~41과)',
#  '골드 프리미엄 시나노 사과 5kg 가정용 (대과)',
#  '가정용흠집 홍로사과 중대과 28-34과 10kg',
#  '[대구경북능금농협] 문경 고당도 감홍 사과 3kg, 10과내',
#  '맘사과 가정용 사과 3Kg 소과(12~13과)',
#  '경북 청송 가정용 홍로사과 10kg',
#  '프레가 사과 선물세트',
#  '[산내들]명품 밀양얼음골 사과선물세트 4.5kg(15과)',
#  '노란 황금사과 시나노골드 제철 과일 경북 의성 예산 감홍 홍옥 사과 3kg 5kg',
#  '나주배 가정용 고당도 햇배 15kg 흠집배 못난이배',
#  '[2022햇사과] 산지애 씻어나온 꿀사과 3kg 1box (대과)',
#  '[산들네] 껍질째 먹는 경북 세척사과 5kg 25과내',
#  '나주배 7.5kg 11-12과 선물세트',
#  '나주배 가정용 고당도 햇배 5kg 흠집배 못난이배',
#  '때깔찬 홍로 가을사과 실중량 9kg (중소과/52과내외)',
#  '당도선별 아삭아삭 빨간 햇사과 (시나노사과) 중과 10kg',
#  '황금사과 시나노골드 10kg 주스용 노란사과 상급',
#  '[8/30(화)부터순차출고] [GAP인증]청송주왕산 사과세트 8kg(38-42과)',
#  '당도선별 아삭아삭 빨간 홍로사과 가정용 소과 10kg',
#  '[2022햇사과] 산지애 씻어나온 꿀사과 3kg 2box (대과)',
#  '[산들네] 껍질째 먹는 경북 세척사과 5kg 25과내',
#  '[더조은] 경북 아오리 사과 실속 세척사과 5kg 25-28과',
#  '꿀맛남 나주배 5kg (가정용/5-9과)',
#  '달아달아 양광 사과 3kg(14-15과) 1박스',
#  '[나주직송] 가정용 나주 신고배 5kg (10~12과)',
#  '세척사과 실중량 10kg(33~50과)',
#  '[이슬마루] 황금사과 시나노골드 3kg(16~21과)',
#  '[웰굿] 경북직송 가정용 감홍 사과 2.5kg(7과내,대과)',
#  '나주배 7.5kg 11-12과 가정용/상품',
#  '나주배 3kg 5-6과+사과 2.3kg 9과 실속세트',
#  '[산지직송] 껍질째 먹는 산들네 세척사과 5kg 28과내',
#  '인정가득 하루 한 사과 / 주스용 갈아먹는 특대과 10kg (24-40과내)',
#  '문경 자이언트 사과 (4입/팩)',
#  '[산들네] 껍질째 먹는 경북 세척 꼬마사과 4.5kg 28-33과내',
#  '청송 시나노골드 5kg 19-22 중과 황금사과',
#  '나주배 햇 나주배 황금 신고 화산 서생 원황 꿀 7.5kg',
#  '[경북농협] 자연의 맛을 담은 남상주 세척사과 3kg, 5kg, 7.5kg',
#  '산지직송 나주배 GAP 인증 가정용 배 / 특품 / 과일선물세트 (9017)',
#  '[2022햇사과] 산지애 씻어나온 꿀사과 3kg 2box 대과',
#  '경북 청송 홍로사과 선물세트 고급 5kg',
#  '저탄소 배 (2입/팩)',
#  '[산들네] 껍질째 먹는 경북 세척사과 5kg 28과내',
#  '당도선별 아삭아삭 빨간 홍로사과 가정용 중과 10kg',
#  '당도선별 아삭아삭 빨간 홍로사과 가정용 대과 2kg',
#  '[22년 햇사과]달아달아 세척사과 양광 1박스 + 시나노스위트 1박스(각2.8kg)',
#  '경북 가정용 홍로 사과 못난이 흠집 쥬스용 사과',
#  '[웰굿]강원도 홍천 실속형 사과세트 5kg(20과)',
#  '정품 햇 사과 4kg 중대과(15과내외)',
#  '[웰굿] 경북직송 가정용 감홍 사과 3kg(10-11과,중과)',
#  '경북 루비에스 미니사과 3kg 30~39과 내외 랜덤',
#  '[더조은] 아리수 사과 가정용 5kg 16-18과',
#  '[1+1][이슬마루] GAP 저탄소 세척사과 2.5kg(13~16과)x2박스',
#  '[청송사과] [산지직송]명품 안동사과 5kg(16-24과/중과 정품)',
#  '[산지직송] 의성 황금사과(시나노골드) 대 2kg',
#  '경북 경산 사과대추 400g (특대~대)',
#  '이츠올릿 경북 시나노 골드 황금 꿀사과 5kg (가정용 중대과 13-15과) 노란 스위트 사과 청송 밀양 얼음골',
#  '경북 데일리 홍로사과 6kg(24-28과)',
#  '경북 가을 사과 3kg( 16-17과내외)소',
#  '아삭아삭 시원한 달콤 당도선별 정품 햇배 대과 10kg',
#  '사과 특대과 5kg(14-16과)',
#  '경북 안동 청송사과 시나노골드 노란 황금사과 꿀사과 가정용 소과 3KG',
#  '산지직송 정품 나주신고배 4.5kg(11과내외)',
#  '화산배 7.5kg (9-10과) 대과',
#  '햇사과 홍로 12-13브릭스 고당도 22년 수확 경북 대구 홍로 5kg',
#  '[2022햇사과] 산지애 알뜰 못난이사과(대과) 4kg 2box',
#  '[GAP인증]문경 A+사과 5kg(17 19과)',
#  '[자연맛남] 아삭아삭 세척사과 3kg (17과내)',
#  '[함초롬] 껍질째 먹는 세척사과 5kg (20-23내)',
#  '내입에 보조개사과 9kg',
#  '사과 5kg 10kg 중대과 대과 정품 가정용 실속형',
#  '[더조은] 경북 아오리 사과 실속 10kg 48-51과',
#  '[대통령상 수상] 나주신고배 선물세트 15kg(21-26과)',
#  '농협 햇살담은 알뜰 천안신고배 5kg',
#  '[싱싱유통]바른 가정용 세척사과 실중량 2.5kg 12-14과 X 2박스',
#  '햇배 화산배 3.5kg (6-7과) 중과',
#  '배 B+ (2-5입/봉)',
#  '사과 소과 5kg(20-23과)',
#  '맘사과 가정용 사과 3Kg 대과(6~7과)',
#  '[자연맛남] 아삭아삭 사과 4kg (18과내)',
#  '[대통령상 수상] 탑푸르트 나주신고배 선물세트 7.5kg(11~13과)',
#  '[나주직송] 나주 추황배 5kg (11-15과)',
#  '[2022햇사과] 산지애 알뜰 못난이사과(중과) 4.5kg 2box',
#  '[이슬마루] 껍질째먹는 세척사과 부사 2.5kg (13~16과)',
#  '더자인 경북 시나노골드 황금사과 2kg 3kg',
#  '사과 소과 10kg(40~46과)',
#  '털보네 고당도 꿀사과 5kg',
#  '맘사과 가정용 사과 10Kg 소과(42~49과)',
#  '산지애 사과원액주스 60팩 / 사과즙, 100% 착즙, NFC',
#  '경북 사과 꼬마소과 4kg 30과 내외 (가정용)',
#  '울산 서생배 신고배 가정용 특대과 5kg 7.5kg 10kg 15kg',
#  '껍질째 먹는 경북 세척사과 5kg 22과내',
#  '[우체국쇼핑] 전남 나주 안영일님의 나주배5kg 가정용(10-12수)',
#  '[2022햇사과] 씻어나온 꿀사과 3kg 2box (대과)',
#  '22년 나주배 3kg (가정용/8과내)',
#  '경북 사과 중과 4kg 18과 내외 (가정용)',
#  '경북 사과 중소과 4kg 21과 내외',
#  '[2022햇사과] 산지애 알뜰 못난이사과(소과) 4.5kg 1box',
#  '[사과랑] 껍질째먹는 세척사과 4kg (23과내)',
#  '가정용 햇 사과 4kg 중대과(15과내외)',
#  '[착한식탁] 주스용 햇 빨간사과 9.5kg 랜덤과',
#  '[인정한과일] 주스용 갈아먹는 사과 10kg (33-46과내)',
#  '[대통령상 수상] 나주신고배 선물세트 5kg(8~9과)',
#  '안동 가을 맛있는 홍로 꿀 아침 사과 2kg 3kg 5kg 산지직송',
#  '경북 사과 대과 4kg 12과 내외 (가정용)',
#  '경북 사과 소과 4kg 24과 내외 (가정용)',
#  '장수사과 5kg(15과)',
#  '[명가일품] [애플팩토리] 알뜰 세척사과 2kg (11과내외/기스,흠과 사과)',
#  '경북 청송 가정용 홍로사과 10kg',
#  '장수사과 5kg(13과)',
#  '[더조은] 아리수 사과 가정용 5kg 19-21과',
#  '대한민국 국내산 시나노골드사과 중대과 10kg 33과내외',
#  '[해민푸드]품격높은 신고배 선물세트 7.5kg(8-10과)',
#  '[감미로이]자연담은 사과 선물세트 4.5kg(12-14과)',
#  '[내당농산]롯데백화점 명품 신고배 세트 추석명절 과일선물',
#  '꿀맛남 나주배 5kg (가정용/10-12과)',
#  '아삭아삭 시원한 달콤 당도선별 정품 햇배 소과 5kg',
#  '껍질째 먹는 경북 세척사과 3kg 15과내',
#  '청송 얼음골 꿀 사과 홍로 2kg 4.5kg',
#  '청송 시나노골드 5kg 13-17 대과 황금사과',
#  '청송 시나노골드 10kg 38-44 중과 황금사과',
#  '자연담움 고당도 명품 배 7.5kg 8-10과 설날 당일수확',
#  '22년 청송사과 햇사과 황금사과 노란사과 시나노골드 3kg 5kg 10kg',
#  '가정용 나주배 7.5kg 7-10과',
#  '고당도 프리미엄 나주배 선물용 선물세트 7.5kg',
#  '가정용 못난이 대사이즈 나주배 5kg',
#  '털보네 고당도 꿀사과 9kg 내외 / 알뜰사과 5kg',
#  '[이슬마루] 부사 경북 의성 사과 흠과 10kg (52~65과)',
#  '맛 좋고 아삭한 울산 서생배 맛나 5kg 7.5kg 10kg 가정용',
#  '[싱싱유통]홍로 세척사과 실중량 5kg (20-30과 내외) 꼬마소과',
#  '22년 햇 나주배 5kg 가정용 6~13과 내외 신고배',
#  '[제]양광사과4~8입/봉(슈퍼)',
#  '명품 의성 사과선물세트 1호',
#  '가정용흠집 홍로사과 중소과 39-43과 10kg',
#  '가정용흠집 홍로사과 소과 44-47과 10kg',
#  '[산지직송] 경북 아삭아삭 사과 8kg (32과내외)',
#  '[산지직송] 경북 아삭아삭 사과 8kg (37과내외)',
#  '괴산 시나노골드 대과 5kg 19-22과 황금사과',
#  '[대통령상 수상] 나주신고배 선물세트 15kg(18-20과)',
#  '[산지직송] 경북 아삭아삭 사과 8kg (42과내외)',
#  '껍질째먹는 미니사과 2kg(개당30-40g)',
#  '껍질째먹는 미니사과 2kg(개당60g내외)',
#  '경북 가을 사과 3kg(18-22과내외)꼬마소과',
#  '경북 가을 사과 4.5kg(18-20과내외)중',
#  '시나노골드 정품 소과 5kg 22-24과 황금사과',
#  '[산지직송] 경북 아삭아삭 사과 2kg (8-10과내외)',
#  '명품 의성 사과/배 과일선물세트 1호',
#  '[산지직송] 경북 아삭아삭 사과 9kg (가정용/63과내외)',
#  '[산지직송] 경북 아삭아삭 사과 3kg (17과내외)',
#  '[산지직송] 경북 아삭아삭 사과 3kg (13과내외)',
#  '청송 시나노골드 10kg 26-34 대과 황금사과',
#  '청송사과 가정용 10kg 랜덤 홍로사과',
#  '시나노골드 정품 중소과 5kg 19-21과 황금사과',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (가정용/20과내외)',
#  '[산지직송] 경북 아삭아삭 사과 8kg (47과내외)',
#  '[산지직송] 경북 아삭아삭 사과 3kg (15과내외)',
#  '명품 의성 사과선물세트 2호',
#  '경북 가을 사과 4.5kg(21-23과내외)중소',
#  '[산지직송] 경북 아삭아삭 사과 2kg (11과내외)',
#  '껍질째먹는 미니사과 2kg(개당40g이상)',
#  '괴산 시나노골드 중소과 5kg 23-26과 황금사과',
#  '가정용흠집 홍로사과 중과(로얄) 35-38과 10kg',
#  '아삭단단 꿀 사과 홍로 부사 청송 문경 안동 3kg 5kg 10kg',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (가정용/33과내외)',
#  '[산지직송] 경북 아삭아삭 사과 2kg (6-7과내외)',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (33과내외)',
#  '시나노골드 가정용 중대과 5kg 13-15과 황금사과',
#  '22년수확 홍로사과 중대과 10kg 28-33과',
#  '[산지직송] 경북 아삭아삭 사과 3kg (22과내외)',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (20과내외)',
#  '빛가득 제철사과 10kg (41-50과)',
#  '국내산 신고배 5kg 7과 특과',
#  '껍질째먹는 미니사과 2kg(개당30-40g)',
#  '껍질째먹는 미니사과 2kg(개당60g내외)',
#  '달콤하고 시원한 과즙이 입안가득~ 건강 배 (중 15kg)',
#  '시나노골드 정품 중대과 5kg 13-15과 황금사과',
#  '[산지직송] 경북 아삭아삭 사과 9kg (가정용/63과내외)',
#  '[산지직송] 경북 아삭아삭 사과 2kg (9과내외)',
#  '[산지직송] 경북 아삭아삭 사과 3kg (11과내외)',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (23과내외)',
#  '달콤하고 시원한 과즙이 입안가득~ 건강 배 (중 10kg)',
#  '시나노골드 정품 중과 5kg 16-18과 황금사과',
#  '달콤하고 시원한 과즙이 입안가득~ 건강 배 (중 7kg)',
#  '시나노골드 정품 대과 5kg 10-12과 황금사과',
#  '경북 가을 사과 3kg(18-22과내외)꼬마소과',
#  '경북 가을 사과 4.5kg(18-20과내외)중',
#  '[산지직송] 껍질째먹는 루비에스 사과 2kg (개당 50g내외)',
#  '아삭 시원한 가정용 나주배 3kg(4~6개)',
#  '빛가득 제철사과 10kg (31-40과)',
#  '괴산 시나노골드 특과 3kg 9-10과 황금사과',
#  '[자연맛남] 아삭아삭 세척사과 3kg (17과내) x 2박스',
#  '[3박스][산지직송]명품 안동 세척사과 2.5kg(13-17과/꼬마사과) x 3박스',
#  '[산지직송] 경북 아삭아삭 사과 8kg (58과내외)',
#  '[산지직송] 껍질째먹는 루비에스 사과 2kg (개당 60g내외)',
#  '빛가득 제철사과 10kg (26-30과)',
#  '껍질째먹는 미니사과 2kg(개당60g이상)',
#  '껍질째먹는 미니사과 2kg(개당25-30g)',
#  '껍질째먹는 미니사과 2kg(개당50g내외)',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (17과내외)',
#  '과즙듬뿍 나주배 3kg(4~6개)',
#  '[산지직송] 경북 아삭아삭 사과 2kg (8-10과내외)',
#  '나주배 7.5kg 13-15과 실속형',
#  '[푸른들] 정성담은 명품 나주 신고배 선물세트 1호 6kg(9-10과)',
#  '나주배 3kg 6-9과/가정용',
#  '[산지직송]명품 안동 세척사과 3kg(13-17과)',
#  '[자연맛남] 아삭아삭 사과 4kg (가정용/18과내)',
#  '달콤아삭 경북사과 5kg 19-21과 (중과)',
#  '꿀맛남 나주배 15kg (가정용/21-25과)',
#  '[산지직송] 새콤달콤 미니사과 2kg (중/개당 30-40g)',
#  '나주농협 가정용 신고배 5kg (8과내외)',
#  '[자연맛남] 아삭아삭 사과 4kg (가정용/24과내)',
#  '경북 가을 사과 4.5kg(24-26과내외)소',
#  '달콤아삭 경북사과 가정용 흠과10kg 38-50과(중소과)',
#  '[산지직송] 새콤달콤 미니사과 2kg (소/개당 25-30g)',
#  '아삭 단단 꿀 사과 경북 안동 청송 문경',
#  '[산지직송] 새콤달콤 미니사과 2kg (대/개당 40g이상)',
#  '자연의감동 사과 세트 5kg 15-16과',
#  '꿀맛남 나주배 15kg (가정용/26-30과)',
#  '[자연맛남] 아삭아삭 세척사과 2.5kg (14과내)',
#  '맘사과 가정용 사과 10Kg 한입(50~60과)',
#  '[자연맛남] 아삭아삭 사과 4kg (24과내)',
#  '경북 사과 중과 4kg 18과 내외',
#  '[GAP인증]나주 배 선물세트 5kg (5-7과)',
#  '[GAP]가정용 나주배 3kg(4-7과)',
#  '[산지직송]명품 안동사과 3kg(10-15과/중과 정품)',
#  '[2박스][산지직송]명품 안동사과 3kg(10-15과/중소과 정품) x 2박스',
#  '[GAP]나주직송 가정용 나주배 5kg 15kg',
#  '[사과랑] 껍질째먹는 세척사과 5kg (23과내)',
#  '[내당농산]롯데백화점 명품 홍로사과+신고배 혼합세트 추석명절 과일선물',
#  '22년 추석명절 배 선물세트 7.5kg 보자기포장 감사엽서',
#  '[산들네] 달고 맛있는 경북 꿀맛사과 10kg 36-38과내외 (일반택배포장)',
#  '의성 사과선물세트 2호',
#  '[GAP인증]나주 배 선물세트 7.5kg (8-10과)',
#  '[GAP인증]나주 배 선물세트 7.5kg (11-12과)',
#  '[GAP인증]나주 배 선물세트 5kg (8-10과)',
#  '[자연맛남] 아삭아삭 가정용 사과 9kg (흠과/52과내)',
#  '[GAP]가정용 나주배 3kg(4-7과)',
#  '달콤아삭 경북사과 5kg 15-18과 (대과)',
#  '나주배 7.5kg 13-15과 가정용/상품',
#  '나주배 7.5kg 7-10과 선물세트',
#  '꿀맛남 나주배 15kg (가정용/16-20과)',
#  '대구경북능금농협100번-롯데백화점 프레가 사과세트',
#  '농협선별 전남 배 3kg (가정용/4-7과)',
#  '의성 사과배 혼합선물세트 1호',
#  '[자연맛남] 아삭아삭 세척사과 2.5kg (14과내) x 3박스',
#  '나주배 5kg 6-8과 선물용',
#  '달콤아삭 경북사과 5kg 22-25과 (중소과)',
#  '경북 사과 소과 4kg 24과 내외',
#  '[사과랑] 껍질째먹는 세척사과 4kg (23과내) x 2박스',
#  '[자연맛남] 아삭아삭 가정용 사과 9kg (흠과/28과내)',
#  '[2박스][산지직송]명품 안동 세척사과 2.5kg(13-17과/꼬마사과) x 2박스',
#  '[산지직송]명품 안동 세척사과 5kg(22-27과)',
#  '산지직송 명품 충주알뜰사과(흠과) 10Kg',
#  '[인정한과일] 인정가득 하루 한 사과 / 왕특대과 5kg (10-13과내)',
#  '[인정한과일] 인정가득 하루 한 사과 / 대과 10kg (33-39과내)',
#  '[자연맛남] 아삭아삭 세척사과 3kg (13과내)',
#  '[산들네] 경북사과 선물세트 명품 1호(5kg/15과내)',
#  '[3박스][산지직송]명품 안동사과 3kg(10-15과/중소과 정품) x 3박스',
#  '[자연맛남] 아삭아삭 세척사과 3kg (13과내) x 2박스',
#  '[자연맛남] 아삭아삭 세척사과 2.5kg (14과내) x 2박스',
#  '달콤아삭 경북사과 가정용 흠과10kg 22-36과(중대과)',
#  '[3박스][산지직송]명품 안동 세척사과 3kg(13-17과) x 3박스',
#  '나주배 5kg 9-10과 실속형',
#  '나주배 7.5kg 7-10과 가정용/상품',
#  '[자연맛남] 아삭아삭 가정용 사과 9kg (흠과/랜덤과)',
#  '[인정한과일] 인정가득 하루 한 사과 / 특대과 10kg (27-32과내)',
#  '의성 사과선물세트 1호',
#  '[인정한과일] 인정가득 하루 한 사과 / 왕특대과 10kg (20-26과내)',
#  '[자연맛남] 아삭아삭 가정용 사과 9kg (흠과/40과내)',
#  '[내당농산]롯데백화점 명품 홍로 사과세트 추석 명절 과일선물',
#  '경북 사과 중소과 4kg 21과 내외 (가정용)',
#  '[8/26(금)부터순차출고] GAP인증 나주산포원배세트 5kg 8-10과(선물용)',
#  '제철 홍로 사과 가정용 5kg 중소과(21-23과 내외)',
#  '맘사과 가정용 사과 5Kg 갈아먹는 사과',
#  '[산들네] 껍질째 먹는 경북 세척사과 3kg 15과내 x 2박스',
#  '[2022햇사과] 씻어나온 꿀사과 3kg 1box (대과)',
#  '아름아리 홍로사과 3kg+3kg',
#  '[깊은향기] 유명산지 왕배 세트 1호 7kg [왕배 6입]',
#  '장수사과 10kg(30과)',
#  '명품 의성 사과/배 과일선물세트 2호',
#  '경북 햇 홍로 세척사과 가정용 5kg 19-21과',
#  '시나노 골드 스위트 사과 노란 황금사과 황옥',
#  '[산들네] 껍질째 먹는 경북 세척사과 3kg 15~17과내',
#  '햇배 화산배 7.5kg (13-14과) 중대과',
#  '[베리세상] 국내산 대추사과 1kg (대)',
#  '[산들네] 껍질째 먹는 경북 세척 꼬마사과 3kg 18-22과내',
#  '청송사과 3kg 10-12과 홍로사과',
#  '[착한식탁] 가정용 아오리사과 8kg 중대과 18-38과내외',
#  '맘사과 가정용 사과 5Kg 소과(21~24과)',
#  '가정용 나주 신고배 5kg (5~10과)',
#  '가정용 나주배 3kg (4-9과)',
#  '달콤한 홍로 사과 꿀사과 2kg, 2개 주문시 1kg 증정',
#  '[이슬마루] 경북 의성 사과 흠과 10kg(52~65과)',
#  '경북 경산 사과대추 1.6g (대~중)',
#  '[인정한] 주스용 갈아먹는 사과 10kg (33-46과내)',
#  '[장보리] 영천 하우스 루비에스 미니사과 특상 1kg',
#  '[산들네] 껍질째 먹는 경북 세척사과 2kg 9과내 (중과)',
#  '[착한식탁]바른 가정용 세척사과 실중량 5kg 20-30과',
#  '(산포원예) GAP인증 나주배(가정용) 7.5kg(11-12과)',
#  '[방씨아들] 꿀 경북 청송 햇 사과 부사사과 선물용 중대과 5kg(18과수내외)',
#  '[나주직송] 나주 추황배 5kg (5~10과)',
#  '[미네픽] 새콤달콤 황금빛 청송 시나노 골드사과',
#  '사과 소과 10kg(40-46과)',
#  '꿀과즙 아삭한 식감 청송 홍로사과 고급 10kg 선물세트',
#  '가정용 나주배 7.5kg 11-12과',
#  '가정용 나주배 7.5kg 13-15과',
#  '명품 사과 선물세트 4kg (12과내)',
#  '[대통령상 수상] 나주신고배 선물세트 7.5kg(7-8과)',
#  '[애플팩토리] 껍질째 먹는 봉지 세척사과 2.5kg (8-15과)',
#  '[] 남상주 데일리 세척사과 7.5kg(30-34과)',
#  '햇 아름아리 사과 3.5kg+배 4.5kg',
#  '[2022햇사과] 알뜰 못난이사과(중과) 4.5kg 2box',
#  '[2022햇사과] 알뜰 못난이사과(대과) 4kg 2box',
#  '경북 데일리 홍로사과 6kg (24-28과)',
#  '(인빌푸드)의성춘산사과(시나노골드) 5kg(기스)',
#  '아름아리 못난이 사과 3.5kg+3.5kg',
#  '[인정한과일]하루 한 사과 / 주스용 갈아먹는 중대과 10kg (33...',
#  '경북 아오리사과 정품 10kg',
#  '[장보리] 경북 청송 가정용 홍로사과 5kg',
#  '경북 홍로 사과 가정용 10kg 48-51과',
#  '가정용 신고배7.5kg(13과 내외) 팔팔마켓 흡집 과일배',
#  '[베리세상] 국내산 대추사과 1kg (상)',
#  '[나주직송] 나주 추황배 5kg (11~15과)',
#  '[청송사과] [산지직송]명품 안동 세척사과 2.5kg(13-17과/꼬마사과)',
#  '새콤달콤 한입 미니사과 루비에스 특상1kg 햇사과',
#  '[더조은] 아리수 사과 가정용 5kg 22-24과',
#  '가정용 햇 사과 4kg 중과(17과내외)',
#  '사과 [이슬마루] 껍질째먹는 세척사과 2.5kg(13~16과)',
#  '[싱싱유통]가정용 아오리사과 8kg 꼬마소과 32-48과내외',
#  '한입 꼬마사과 10kg 50~70과 (가정용)',
#  '즙쟁이 케일사과즙 1박스 30포',
#  '[신북농협] 신고배 실속형 5kg (6~8과/9~10과/11~12과)',
#  '강원도 정선 명품사과 가정용사과 3kg(12-13과) 햇사과 홍로',
#  '배 한상자 성환배 천안배 흠집배 햇배 못난이배 꿀배 2kg 4kg 15kg',
#  '[2박스구매+1kg]경북 가정용 사과 4kg(25-35과,꼬마)',
#  '사과(가정용) 3kg 10-15과',
#  '[착한식탁] 가정용 아오리사과 3kg 중대과 7-13과내외',
#  '세척사과 3kg+3kg(20~30과)',
#  '[햇살아름] 당도선별 배 선물세트1호 6.8kg이상(11-13과내)',
#  '[이룸팜스] 다복 나주배 고급선물세트 7.5kg(9-10과)',
#  '아삭달콤 제철 빨간 햇사과 5kg 중과(18-24과내외)',
#  'A급 가정용 나주배 신고배 3kg 4-7과',
#  '[산내들] 명품 밀양얼음골 사과선물세트 4.5kg(13과)',
#  '프리미엄 신고/화산 배세트(7.5kg, 특대 9과내외)/선물용 인기과일/물많고 시',
#  '경북 햇 홍로 세척사과 가정용 3kg 11-15과',
#  '맘사과 가정용 사과 5Kg 한입(25~30과)',
#  '[산지직송] 과즙가득 의성 흠집 사과(대) 4kg',
#  '경북 홍로 사과 정품 10kg',
#  '[착한식탁]홍로 세척사과 실중량 5kg 20~30과 내외 꼬마소과',
#  '[싱싱유통]가정용 아오리사과 8kg 중대과 18-38과내외',
#  '(강원)[선물용]GAP인증 부사사과 5kg 15과',
#  '[맘스킹]창성 강원정선 고랭지 더덕청/도라지청/인삼청선물세트',
#  '[산내들] 명품 밀양얼음골 사과선물세트 4.5kg(12과)',
#  '[햇살아름]당도선별 진품사과, 배 ,메론선물세트7.1kg이상 (사과4개,배3개, 메',
#  '경북 햇 홍로 세척사과 정품 5kg 19-21과',
#  '명절 신고배 선물세트 5kg (5~6과) / 특품',
#  '[웰굿] 경북직송 가정용 감홍 사과 9kg(30-35과,중과)',
#  '야과몰 가을햇살 머금은 맛있는 사과대추 대추사과',
#  '[싱싱유통]가정용 아오리사과 꼬마소과 3kg 13-26과내외',
#  '나주배 선물용 선물세트 고당도 햇배 7.5kg',
#  '[우체국쇼핑] 전남 나주 안영일님의 나주배5kg 가정용(8-9수)',
#  '(강원)[선물용]GAP인증 부사사과 5kg 13과',
#  '[산지직송] 경북의성 사과 10kg(55~69과내외)',
#  '아삭아삭 국내산 사과 2kg(9-10개입)',
#  '슬로푸드 명품 하동 햇배 7.5kg (8~10과) 선물용',
#  '[8/26(금)부터순차출고] 웰빙나주배 7.5kg(9-10과)',
#  '(강원)[선물용]GAP인증 부사사과 5kg 17과',
#  '청년농부 아삭아삭 나주배 3kg 4-8과 (가정용)',
#  '[이룸팜스] 다복 명품나주배 선물세트 5kg(6-8과)',
#  '[햇살아름]당도선별 명품 사과 선물세트 3.2kg이상(사과9과/특품)보자기포장',
#  '세척사과 10kg(33~50과)',
#  '의성 달콤한 금빛사과 시나노골드 꼬마 3kg',
#  '[AKmall][식품][방씨아들] 최상급 고당도 사과대추 왕대추 2kg',
#  '사과 2 5kg 아오리 홍옥 홍로 감홍 시나노 골드 스위트 황옥 부사 양광 미니 부사 1001965',
#  '[웰굿] 경북직송 가정용 감홍 사과 9kg(28과내,대과)',
#  '국내산 명품 사과대추 1kg 중상 (28mm 내외)',
#  '[산지직송] 의성 황금사과(시나노골드) 특 5kg',
#  '사과 왕특대과 5kg(10-13과)',
#  '푸른사과 아삭한 햇 꿀 사과 아오리사과 2kg/2개주문시 1kg서비스',
#  '영화농산 5kg 사과유명한곳 꿀사과 농장',
#  '가정용 흠과 사과4kg(19-21과) 중과',
#  '아침애사과-가정용사과 5kg',
#  '당도선별 아삭아삭 빨간 햇사과 (시나노사과) 중과 5kg',
#  '(산포원예)GAP인증 가정용 나주배 15kg 21-25과',
#  '[햇살아름]당도선별 배 선물세트2호 6.8kg이상(8-10과내)',
#  '슬로푸드 명품 하동 햇배 7.5kg (11~13과) 선물용',
#  '[착한식탁] 햇 빨간사과 정품 중대과 7kg',
#  '[8/26(금)부터순차출고] GAP인증 나주산포원배세트 7.5kg 8-10과(선물용)',
#  '[자연품애]껍질채먹는 세척 사과 5kg',
#  '[인정한과일] 인정가득 하루 한 사과 / 주스용 갈아먹는 사과 10kg (20-40과내)',
#  '[이랑농장]미안마 부사 *선물용[10kg]34과',
#  '산지직송 청송 가정용 사과 부사 9kg 25~30과',
#  '[8/26(금)부터순차출고][참다올] 명절선물세트-배세트2호( 7.5kg 8-10과)',
#  '청년농부 아삭아삭 나주배 5kg 6-7과 (가정용)',
#  '[8/26(금)부터순차출고] GAP인증 나주산포원배세트 5kg 5-7과(선물용)',
#  '[웰굿] 경북직송 가정용 감홍 사과 5kg(17과내,대과)',
#  '[식탐대첩]식탐대첩 심한 가정용 흠집 주스용 부사사과 10kg',
#  '[선물용]GAP인증 부사사과 10kg 30과',
#  '마음담은 사과 9kg(54~60과_흠집)_실중량',
#  '의성에서 보내드리는 꿀당도 아삭달콤 세척사과 (중)4kg',
#  '[이레뜰] 세척사과 총 6kg(3kg X 2박스)',
#  '경북 청송 홍로 사과 꿀사과 흠집 쥬스용 6.5kg',
#  '[웰굿] 경북직송 가정용 감홍 사과 9kg(36-39과,중소과)',
#  '시나노골드 황금사과 새콤달콤 아삭한 맛있는 고당도',
#  '[문경농협] 문경 고당도 감홍 사과 3kg 10과내',
#  '황금사과 사과 5kg 10kg 시나노골드 황금 꿀사과',
#  '감홍사과 경북 문경사과 꿀 당도보장 가정용 흠집 3kg 5kg 10kg',
#  '[웰굿] 경북직송 가정용 감홍 사과 2.5kg(11-12과,중소과)',
#  '[산지직송] 의성 황금사과(시나노골드) 대 4kg',
#  '[산지직송] 의성 황금사과(시나노골드) 특 3kg',
#  '[대한농산] 정품 홍옥 사과 2kg내외(10과내외)',
#  '경북 청송 부사 홍로 사과 꿀사과 흠집 가정용 3kg 중과 로얄 (11-15과)',
#  '달달한 황금 성환배 4.5kg 11-12과',
#  '[2022햇사과] 산지애 알뜰 못난이사과대과 4kg 2box',
#  '국내산 명품 사과대추 1kg 왕특 (37mm 내외)',
#  '영천 햇 미니사과 루비에스사과 꿀사과 2kg',
#  '산지직송 안동사과 시나노골드 황금 사과 5kg 10kg',
#  '[웰굿] 경북직송 가정용 감홍 사과 2.5kg(7과내,대과)',
#  '[청송팜] 22년 청송 꿀사과 시나노스위트 5kg 19-20과 선물용',
#  '[AKmall][식품][방씨아들] 최상급 고당도 사과대추 왕대추 1kg',
#  '[웰굿] 경북직송 가정용 감홍 사과 3kg(9과내,대과)',
#  '[싱싱유통]맛있는 사과 10kg 주스용 (랜덤과)',
#  '[2022햇사과] 산지애 알뜰 못난이사과(소과) 4.5kg 1box',
#  '이츠올릿 경북 시나노 골드 황금 꿀사과 5kg (가정용 대과 10-12과) 노란 스위트 사과 청송 밀양 얼음골',
#  '[G]여름과일 - 아오리사과 5kg(17-23개내외)',
#  '경북농협 문경 ABC 보조개 사과',
#  '[대구경북능금농협] 경북 영천 황금사과(시나노골드) 3kg 12과내/14과내',
#  '고당도 빨간 사과 가정용 감홍 7kg 대과 (24과내)',
#  '발바닥굳은살 패디플래닝 손가락',
#  '대한민국 국내산 아리수사과 10kg 44과내외',
#  '자연애 세척사과 3kg(14-18과) 중소과',
#  '[산들네] 껍질째 먹는 경북 세척사과 3kg 13과내',
#  '아삭하고 과즙풍부 나주 신고배 3kg (4-7과)가정용',
#  '[웰굿] 경북직송 가정용 감홍 사과 9kg(30-35과,중과)',
#  '[웰굿] 경북직송 가정용 감홍 사과 3kg(9과내,대과)',
#  '장수사과 10kg(34과)',
#  '[장보리] 국내산 명품 사과대추 1kg 왕특 (37mm 내외)',
#  '달빛사과 양광 세척사과 꿀사과 햇사과 3kg 14~15과',
#  '달고 맛있는 경북 꿀맛사과 10kg 36~38과내외',
#  '정품사과 5kg 20-25과 선별과',
#  '경북 안동 김권수님의 세척사과 3kg 14과내',
#  '껍질째 먹는 세척사과 2.5kg(12과내)',
#  '[셀러허브 생활리빙][자연예서] 홍로 햇사과 5kg (11-13과) ...',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 대과 9kg(25-29과)',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 대과 3kg(9과내)',
#  '가정용 나주배 15kg 16-20과',
#  '집에서 즐기는 실속 햇 부사 사과 4kg/8kg 과수선택',
#  '산정마을 나주배 고당도 햇배 가정용 5kg 15kg',
#  '영주 세척사과 황금사과 아침부터멋 2.5kg(단품) 시나노골드',
#  '피크닉 사과 10kg (46과)',
#  '피크닉 사과 10kg (50과)',
#  '[정품] 꿀담은 햇 빨간사과 2kg 과수선택',
#  '남상주농협외남지점 세척사과 5kg 17-19과',
#  '영천 미니사과 달콤한 알프스오토메 데코용 2kg(25-30g)',
#  '가정용 나주배 15kg 21-25과',
#  '껍질째 먹는 경북 세척사과 3kg 15과내 x 2박스',
#  '달아달아 양광 세척사과 4.5kg(21-23과) 2박스',
#  '[착한식탁] 바른 가정용 세척사과 실중량 5kg 20-30과',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 중과 9kg(32-46과)',
#  '집에서 즐기는 실속 햇 빨간사과 8kg 과수선택',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 대과 3kg(9과내)',
#  '달고 맛있는 경북 꿀맛사과 3kg 15-17과 x 2박스 (총 6kg)',
#  '[이레뜰] 명품 사과배혼합 선물세트 5.5kg(사과5과+배6과내외)',
#  '집에서 즐기는 실속 햇 빨간사과 4kg 과수선택',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 소과 3kg(17과내)',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 소과 2.5kg(15과내)',
#  '[산지직송] 정성들여 키운 달콤한 나주 신고배 3kg (5-6과)',
#  '[미미의 밥상][정품] 꿀담은 햇 시나노골드 사과 3kg 중과 (13...',
#  '정품 제철 경북산 햇 사과 모음',
#  '황금사과 시나노골드 소과 5kg 22-24과 가정용 노란사과',
#  '[2022햇사과] 산지애 씻어나온 꿀사과 3kg 1box 대과',
#  '경북 안동 김권수님의 세척사과 3kg 14과내',
#  '안동 시나노 골드 사과 황금 노란 아침 꿀 사과 2kg 3kg 5kg 산지직송',
#  '산정마을 나주배 고당도 햇배 가정용 5kg 15kg',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (가정용/20과...',
#  '[AKmall]경북 부사 사과 4.5kg 중소과 22과내외 (가정용)',
#  '[AKmall]경북 부사 사과 5kg 중소과 24과내외 (가정용)',
#  '[AKmall]경북 부사 사과 5kg 대과 15과내외 (가정용)',
#  '[정품] 꿀담은 햇 빨간사과 4kg 과수선택',
#  '[산지직송] 경북 아삭아삭 사과 8kg (47과내외)',
#  '황금빛 금사과 시나노골드 3kg/5kg',
#  '서양배 스위트센세이션 2kg 6-14과',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 7kg 간식(33-41과)',
#  '[자연품애]새콤달콤 가정용 사과 7kg 소과',
#  '[2022햇사과] 산지애 알뜰 못난이사과대과 4kg 1box',
#  '[미미의밥상] 달달한 황금 성환배 4.5kg 11-12과',
#  '[산지직송] 경북 아삭아삭 사과 8kg (32과내외)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 4kg 대과 (12과내)',
#  '필수과일, 아삭아삭 햇사과 감홍부사2kg/3kg',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 소과 9kg(48-60과)',
#  '[셀러허브 생활리빙][자연예서] 홍로 햇사과 5kg (11-13과) ...',
#  '나주농협 가정용 신고배 3kg (5과내외)',
#  '[산지직송] 경북 아삭아삭 사과 9kg (가정용/63과내외)',
#  '피크닉 사과 10kg (40과)',
#  '[AKmall]경북 부사 사과 4.5kg 소과 25과내외 (가정용)',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 5kg 간식 (23-28과)',
#  '[힛더스팟 내입에] [내입에] 보조개사과 흠집사과 알뜰사과 9kg(3kgx3박스)',
#  '정품사과 5kg 20-25과 선별과',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 8kg 중과 (34과내)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 4kg 중대과 (15과...',
#  '정품사과 10kg 40-50과 선별과',
#  '[8월29일부터 순차출고] 나주배 5kg 6-8과+사과 3.5kg 10-11과 선물세트',
#  '아산배 농협배 산지직송 서양배 스위트센세이션 1kg 2kg 유렵배',
#  '가정용 나주배 15kg 16-20과',
#  '집에서 즐기는 실속 햇 부사 사과 4kg/8kg 과수선택',
#  '피크닉 사과 5kg (23과)',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 5kg 중과 (19-22과)',
#  '[AKmall]경북 부사 사과 10kg 소과 60과내외 (가정용)',
#  '[산지직송] 경북 아삭아삭 사과 8kg (47과내외)',
#  '[산지직송] 정성들여 키운 달콤한 나주 신고배 5kg (9-10과)',
#  '[청송팜] 꼬마사과 시나노스위트,홍로 혼합 8kg 46~50과내외',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 중과 2.5kg(12과내)',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 5kg 중과 (19-22과)',
#  '[자연품애]새콤달콤 가정용 사과 7kg 소과',
#  '맛있는家 껍질째먹는 루비에스 사과 2kg 개당 50g내외 外 크기별',
#  '[2022햇사과] 산지애 알뜰 못난이사과대과 4kg 1box',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 7kg 간식(33-41과)',
#  '[미미의밥상] 달달한 황금 성환배 4.5kg 11-12과',
#  '[산지직송] 경북 아삭아삭 사과 8kg (32과내외)',
#  '빛가득 제철사과 10kg 41-50과',
#  '[달콤이네상콤이네] 명품 추석 사과배혼합선물세트 6.5kg 내외12과',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 4kg 대과 (12과내)',
#  '선물용 나주배 7.5kg 맛있는 명품 신고배 판매 진맛깔',
#  '필수과일, 아삭아삭 햇사과 감홍부사2kg/3kg',
#  '[좋은맛닷컴][초록자연] 홍로 햇사과 10kg (50과 내외) 선물세트',
#  '[좋은맛닷컴][초록자연] 홍로 사과 선물세트 5kg (11-13과) ...',
#  '정품 경북 전해수 껍질째 세척사과 3kg 10~12 5kg 20~23,17~19 과수',
#  '영천 미니사과 달콤한 알프스오토메 데코용 2kg(30-40g)',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 소과 9kg(48-60과)',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 5kg 간식 (23-28과)',
#  '아름아리 못난이 사과 3.5kg+3.5kg',
#  '[셀러허브 생활리빙][자연예서] 홍로 햇사과 5kg (11-13과) ...',
#  '[지투지샵]사과 3kg 9-10과',
#  '[지투지샵]사과 3kg 11-13과',
#  '[지투지샵]사과 5kg 23-26과',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 8kg 중과 (34과내)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 4kg 중대과 (15과...',
#  '[AKmall]경북 부사 사과 4.5kg 소과 25과내외 (가정용)',
#  '꿀과즙 아삭한 식감 청송 홍로사과 일반 5kg 선물세트',
#  '아삭한 식감 풍부한 과즙 새콤달콤 청송 홍로사과 3kg 13-15과',
#  '새콤달콤한 햇 꿀사과 홍로사과 2kg 중소과 10과 내외',
#  '[AKmall]경북 부사 사과 10kg 소과 60과내외 (가정용)',
#  '[AKmall]경북 부사 사과 5kg 중과 21과내외 (가정용)',
#  '[힛더스팟 내입에] [내입에] 보조개사과 흠집사과 알뜰사과 9kg(3kgx3박스)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 부사 사과 8kg 대과 (24과...',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (20과내외)',
#  '[산지직송] 경북 아삭아삭 사과 9kg (가정용/63과내외)',
#  '나주농협 가정용 신고배 3kg (5과내외)',
#  '[농협] 남상주 데일리 세척사과 5kg(17-19과)',
#  '사과 왕특대과 10kg(20-26과)',
#  '[이레뜰] 명품사과선물세트 2호 5kg 18과내외',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 7kg 소과 (42-58과)',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 중과 9kg(32-46과)',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 5kg 대과 (18과내)',
#  '황금빛 금사과 시나노골드 3kg/5kg',
#  '[산지직송] 정성들여 키운 달콤한 나주 신고배 3kg (5-6과)',
#  '피크닉 사과 10kg (46과)',
#  '피크닉 사과 10kg (50과)',
#  '집에서 즐기는 실속 햇 빨간사과 4kg 과수선택',
#  '달고 맛있는 경북 꿀맛사과 3kg 13과내외',
#  'GNM자연의품격 물 넣지 않은 100 NFC 착즙 경북 사과즙 2박스 (총 60포)',
#  '집에서 즐기는 실속 햇 빨간사과 10kg 과수선택',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 7kg 중과(25-32과)',
#  '정품 제철 경북산 햇 사과 모음',
#  '서양배 스위트센세이션 2kg 6-14과',
#  '집에서 즐기는 실속 햇 빨간사과 8kg 꼬마소과 (50-60과내)',
#  '집에서 즐기는 실속 햇 빨간사과 8kg 대과 (24과내)',
#  '[농장직송] 프리미엄 신고배 선물세트 명품 3호 7.5kg/11과',
#  '가정용 나주배 15kg 21-25과',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 소과 2.5kg(15과내)',
#  '수창이네:마켓 새콤달콤 맛의 조화 시나노골드 가정용 소과 3kg(17과내)',
#  '경북 청송 홍로사과 3kg 10-12과',
#  '경북 영천 황금사과 시나노골드 3kg 14과내',
#  '[착한식탁] 바른 가정용 세척사과 실중량 5kg 20-30과',
#  '경북 영천 황금사과 시나노골드 3kg 12과내',
#  '[달콤이네상콤이네] 명품 추석 배선물세트 8.5kg 내외 특대과12',
#  '[2022햇사과] 산지애 알뜰 못난이사과소과 4.5kg 1box',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 7kg 대과(24과내)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 부사 사과 8kg 소과 (46과...',
#  '[산지직송] 경북 아삭아삭 사과 2kg (11과내외)',
#  '[산지직송] 경북 아삭아삭 사과 3kg (15과내외)',
#  '피크닉 사과 3kg (15-17과내)',
#  '[미미의 밥상][정품] 꿀담은 햇 빨간사과 2kg 중대과 (7과내외)',
#  '[산지직송] 경북 아삭아삭 사과 3kg (13과내외)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 8kg 대과 (24과내)',
#  '[꿀이구마] 프리미엄 사과 선물세트 5kg 11과 내외',
#  '[꿀이구마] 프리미엄 배 선물세트 7.5kg 7~10과',
#  '껍질째 먹는 세척사과 대 5kg 14-16입',
#  '[열매나무] 못난이 사과 2kg 8~11과',
#  '홍로 사과 GAP 햇사과 꿀사과 고랭지사과 4kg',
#  '선물용-나주 햇배(신고) 특품 (22년) 7.5kg (11-13과)',
#  '선물용-나주 햇배(신고) 특품 (22년) 7.5kg (7-10과)',
#  '[농협] 매일 먹는 데일리 세척사과 5kg(17-19과)',
#  '[농협] 매일 먹는 데일리 세척사과 7.5kg(25-29과)',
#  '[열매나무]리얼푸릇 사과 선물세트 2.5kg',
#  '아침이슬사과 선물세트 5kg 프리미엄 특대과(8-10과)',
#  '아침이슬사과 선물세트 5kg 중소과(18-20과)',
#  '[좋은맛닷컴][초록자연] 홍로 햇사과 10kg (35과 내외) 선물세트',
#  '작고 깜찍해 더욱 맛있는 사과 알프스오토메 400gx2팩/800g',
#  '껍질 째 먹는 고당도 루비에스 사과 2kg (60g이상)',
#  '껍질 째 먹는 고당도 루비에스 사과 2kg (50g내외)',
#  '달아달아 양광 사과 4.5kg(18-20과) 2박스',
#  '산지직송 경북 의성 홍옥 새콤달콤 사과 5kg',
#  '나주배 7.5kg 7-10과 제수용',
#  '[정품] 꿀담은 햇 부사 사과 4kg 대과 (12과내)',
#  '경북 햇 정품 부사 2kg중과/8과내외',
#  '[베리세상] 국내산 대추사과 1kg 대',
#  '[열매나무] 못난이 사과 5kg 17~25과 가정용/중소과',
#  '경북 시나노 골드 햇 사과 3kg 중대과 11과내외',
#  '[열매나무] 못난이 사과 3kg+3kg (박스당 10~18과 / 가정용)',
#  '아삭아삭 청송꿀사과 만 실중량 9kg 38과 홍로/시나노스위트',
#  '국내산 시나노 골드 사과 10과 (2.6kg내외)',
#  '달아달아 양광 사과 3kg(14-15과) 2박스',
#  '[자이담][한터] 충주 황금사과 4.5kg (13-18과)',
#  '[정품] 꿀담은 햇 빨간사과 4kg 중과 (17과내외)',
#  '집에서 즐기는 실속 햇 빨간사과 8kg 중대과 (30과내)',
#  '집에서 즐기는 실속 햇 빨간사과 4kg 중소과 (20과내)',
#  '[정품] 꿀담은 햇 빨간사과 3kg 소과 (17과내외)',
#  '[미미의 밥상][정품] 꿀담은 햇 빨간사과 4kg 중과 (17과내외)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 10kg 소과 (60과...',
#  '집에서 즐기는 실속 햇 빨간사과 4kg 중소과 (20과내)',
#  '집에서 즐기는 실속 햇 빨간사과 8kg 중과 (34과내)',
#  '집에서 즐기는 실속 햇 빨간사과 10kg 소과 (60과내)',
#  '[열매나무] 사과 5kg 12~15과내외 ( 특대과 / 정품)',
#  '[열매나무] 못난이 사과 3kg+3kg (박스당 10~18과 / 가정...',
#  '[보섭이네푸드] 껍질째먹는 미니사과 2kg(개당50g내외)',
#  '[참다올] 프리미엄 나주배 선물세트 7.5kg(9-10과)',
#  '황금사과 시나노골드 꼬마과 5kg 25-28과 가정용 노란사과',
#  '사과 3kg 14-16과',
#  '[정품] 꿀담은 햇 빨간사과 3kg 중대과 (11과내외)',
#  '[청송팜] 22년 청송 꿀사과 시나노스위트 5kg 23-24과 선물용',
#  '[정품] 꿀담은 햇 빨간사과 4kg 중소과 (20과내외)',
#  '[미미의 밥상][정품] 꿀담은 햇 부사 사과 2kg 중소과 (10과내...',
#  '[열매나무] 못난이 사과 3kg+3kg ( 박스당 7~11과 /가정용/대과)',
#  '정품 시나노골드 사과 4kg내외',
#  '[청송팜] 22년 청송 꿀사과 홍로5kg 21-22과 선물용',
#  '[경북의성] 고당도 햇 사과(중) 2kg/8~9과',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (23과내외)',
#  '[산지직송] 경북 아삭아삭 사과 4.5kg (17과내외)',
#  '[산지직송] 새콤달콤 미니사과 2kg [크기별]',
#  '[AKmall]경북 부사 사과 10kg 중대과 40과내외 (가정용)',
#  '아삭한 식감 풍부한 과즙 새콤달콤 청송 홍로사과 3kg 13-15과',
#  '새콤달콤한 햇 꿀사과 홍로사과 2kg 중소과 10과 내외',
#  '아삭한 배 5kg (8과내)',
#  '이츠올릿 경북 시나노 골드 황금 꿀사과 5kg (가정용 중과 16-18과) 노란 스위트 사과 청송 밀양 얼음골',
#  '[경북의성] 황금사과 시나노골드(대) 2kg/7~8과',
#  '[경북의성] 고당도 햇 사과(대) 2kg/7~8과',
#  '산지직송 명불허전 나주 신고배 3kg 6-9과',
#  '달아달아 양광 사과 4.5kg(18-20과) 2박스',
#  '국내산 명품 사과대추 1kg 특대 (32mm 내외)',
#  '[초록자연] 프리미엄 홍로 사과 선물세트 5kg 꿀사과',
#  'SY몰 명품 배 7.5KG 중소기업명절선물 회사추석선물',
#  '[정품] 꿀담은 햇 부사 사과 4kg 대과 (12과내)',
#  '경북 햇 정품 부사 2kg중과/8과내외',
#  '나주배 신고배 A급 가정용 배 5kg 6-12과',
#  '[팜쿡][팜쿡] 무진장 맛있는 경북 홍로 가정용 대 10kg',
#  '[농협] 매일 먹는 데일리 세척사과 5kg(17-19과)',
#  '[농협] 매일 먹는 데일리 세척사과 7.5kg(25-29과)',
#  '[열매나무]리얼푸릇 사과 선물세트 2.5kg',
#  '아침이슬사과 선물세트 5kg 프리미엄 특대과(8-10과)',
#  '아침이슬사과 선물세트 5kg 중소과(18-20과)',
#  '경북 시나노 골드 햇 사과 3kg 중대과 11과내외',
#  '[참다올] 명절 GAP 나주배 선물세트 7.5kg 8-10과',
#  '[열매나무] 못난이 사과 3kg+3kg (박스당 10~18과 / 가정용)',
#  '아삭아삭 청송꿀사과 만 실중량 9kg 38과 홍로/시나노스위트',
#  '[산내들]명품 밀양얼음골 사과선물세트 9kg(24과)',
#  '나주배 7.5kg 7-10과 제수용',
#  '[더조은] 아리수 사과 가정용 3kg 14-16과',
#  '당노 높은 맛있는 가정용 신고배 3kg/5kg',
#  '신고배 선물세트 7.5kg (11-12과)',
#  '[미미의 밥상][정품] 꿀담은 햇 빨간사과 4kg 중과 (17과내외)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 10kg 소과 (60과...',
#  '[참다올] GAP 100년전통 청송사과세트(4kg 12개)',
#  '[참다올] GAP 100년전통 청송사과세트(8kg 34개)',
#  '집에서 즐기는 실속 햇 빨간사과 4kg 중소과 (20과내)',
#  '집에서 즐기는 실속 햇 빨간사과 8kg 중과 (34과내)',
#  '집에서 즐기는 실속 햇 빨간사과 10kg 소과 (60과내)',
#  '[열매나무] 사과 5kg 12~15과내외 ( 특대과 / 정품)',
#  '[열매나무] 못난이 사과 3kg+3kg (박스당 10~18과 / 가정...',
#  '[보섭이네푸드] 껍질째먹는 미니사과 2kg(개당50g내외)',
#  '고급 배 선물세트 7.5kg (5-8과)',
#  '실속 나주배 세트 7.5kg(실중량) 과수/사이즈별',
#  '[베리세상] 국내산 미니사과 알프스오토메 2kg',
#  '국산 노란 골드 시나노 사과 12과 (3.2kg내외)',
#  '맛있는 가정용 흠집배 7.5kg 나주 신고배 판매 진맛깔',
#  '[AKmall]경북 시나노 골드 햇 사과 4kg 대과 12과내외',
#  '[남도장터]나리배농업 나리배 선물용 5kg (5-7과)',
#  '마음담은 사과 3kg(18~23과_흠집)',
#  '황금사과 시나노골드 중대과 5kg 13-15과 프리미엄 노란사과',
#  '추석선물_세트 과일선물 사과 배 1+1 선물세트(알뜰형)_선물포장',
#  '[더조은] 아리수 사과 가정용 5kg 19-21과',
#  '국산 시나노 골드 노란 사과 10과 (2.6kg내외)',
#  '나주배 신고배 정품 5kg 6-10과/대과/ 선별과',
#  '명절 나주배 선물세트 5kg(7~8과) 특품 外',
#  '나주배 7.5kg 7-10과 제수용',
#  '[식품의즐거움] 시나노 골드 정품 햇 사과 실중량 4kg 대과 12과 내(개당 330g내외)',
#  '[참다올] GAP 100년전통 청송사과세트(4kg 12개)',
#  '[참다올] GAP 100년전통 청송사과세트(8kg 34개)',
#  '[프레쉬팜]프리미엄 팔각 배 선물세트 7.5kg(배12과)',
#  '[남도장터]나리배농업 나리배 선물용 7.5kg (13-15과)',
#  '[더조은] 아리수 사과 가정용 5kg 22-24과',
#  '프리미엄팩 사과 5kg(18-20과) +보자기',
#  '프리미엄팩 사과 5kg(21-24과) +보자기',
#  '[더조은] 아리수 사과 가정용 5kg 16-18과',
#  '[자연예서] 홍로 햇사과 10kg (50과 내외) 선물세트',
#  '[팜쿡] 무진장 맛있는 경북 홍로 가정용 대 5kg',
#  '[청송팜] 22년 청송 꿀사과 시나노스위트 5kg 17~18과 선물용',
#  '농협공판장 정성드린 번들 사과 2봉지(봉당5입)',
#  '당도굿 명품선물세트 5kg 14~16과',
#  '[더조은] 아리수 사과 가정용 5kg 25-28과',
#  '양구 펀치볼 꼭지사과 5kg 실속',
#  '양구 펀치볼 꼭지사과 5kg 상품',
#  '[정품]아침애 사과 4kg(16~18과)',
#  '[장길영사과] 장길영 세척사과 10kg (33-50과내)[실중량]',
#  '마음담은 사과 4kg(25~30과_흠집)',
#  '경북 청송 가정용 홍로사과 5kg',
#  '[인정한과일] 인정가득 하루 한 사과 / 대과 5kg (17-19과내)[실중량]',
#  '[자연식탁]경북 가정용 빨간사과 4kg 대과(12과내)',
#  '경북 가정용 빨간사과 8kg 대과(24과내)',
#  '경북 정품 빨간사과 4kg 중과(17과내외)',
#  '[미인과친한]프리미엄 선물세트 사과(특품) 5kg내외(12과),보자기동봉',
#  '달콤한 꿀과즙 듬뿍 펀치볼 양구 홍로사과 선물세트 5kg',
#  '고당도 배 프리미엄 과일선물 인사선물 축하선물 서울청과 가락시장',
#  '[산지직송] 껍질째먹는 루비에스 사과 2kg (개당 60g...',
#  '(깨비농원)고당도 하우스귤 4.5kg 소과(2S)',
#  '나주배 신고배 정품 3kg 4-7/대과/선별과',
#  '양구 펀치볼 꼭지사과 5kg 상품',
#  '양구 펀치볼 꼭지사과 5kg 한입',
#  '경북 청송 홍로사과 3kg 13-15과',
#  '[식탐대첩]명절 선물세트 경북 명품사과 5kgX2박스 (제수용 26-...',
#  '[더싱싱]22년 경북 꿀사과 햇 빨간 사과 2kg(6-7과내외)중대',
#  '가정용흠집 홍로사과 중대과 13-15과 5kg',
#  '가정용흠집 홍로사과 꼬마과 25-28과 5kg',
#  '가정용흠집 홍로사과 꼬마과 48-51과 10kg',
#  '배 선물세트 5kg(8-10과)/GAP인증/나주 직송',
#  '이츠올릿 경북 햇 홍로 부사 꿀 사과 10kg 정품 소과 (44-47과) 껍질째 먹는 가정용 청송 안동 문경 장수',
#  '정품 완숙토마토 찰토마토 10kg 3번',
#  '경북 청송 홍로사과 3kg (10-12과)',
#  '천도 복숭아 4.5kg내외(30과내외)',
#  '아침이슬사과 선물세트 2.5kg 중과(8-10과)',
#  '햇배 나주 신고 특품 추석 명절 선물용 5kg 5~7과',
#  '경북 청송 부사 홍로 사과 꿀사과 흠집 가정용 10Kg 소과 (44-47과)',
#  '맛있는家 대통령상 수상/ 나주신고배 선물세트 5/7.5/15kg',
#  '경북 청송 홍로사과 선물세트 일반 10kg',
#  '[좋은맛닷컴][초록자연] 홍로 햇사과 10kg (30과 내외) 선물용',
#  '스테비아 대추 방울 토망고 500gX4팩',
#  '[웰굿][GAP저탄소인증] 산지직송 나주배 화산배 7.5kg(12-13과,가정용)',
#  '[AKmall][식품][방씨아들]꿀 경북 청송 햇 사과 부사사과 특대과 3kg (9',
#  '맛있는家 [농장직송] 프리미엄 신고배 선물세트 VIP 1호 7.5kg/9과',
#  '[달콤이네상콤이네] 명품 추석 사과선물세트 5kg 내외12과',
#  '[2022햇사과] 산지애 알뜰 못난이사과소과 4.5kg 2box',
#  '작고 깜찍해 더욱 맛있는 사과 알프스오토메 400gx2팩/800g',
#  '제스프리 골드 키위 15과(개당중량 110g내외)',
#  '새콤달콤 햇사과 정품 햇 홍옥사과 5kg',
#  '농협공판장 정성드린 신고배 2봉지/봉당3입',
#  '명절 고급 나주배 선물세트 7.5kg 11-12과',
#  '과즙짱 못난이 상주배 5kg 8~12과',
#  '[나이스파머스] [산지직송] 경북 청송 특고당 꿀사과 9kg (25~30과/중대과)',
#  '피크닉 사과 10kg (36과)',
#  '달아달아 양광 사과 3kg(11-13과) 1박스',
#  '달아달아 양광 사과 4.5kg(18-20과) 1박스',
#  '경북 햇 가정용 부사 4kg소과/23과내외',
#  '국내산 시나노 골드 사과 10과 (2.6kg내외)',
#  '달아달아 양광 사과 3kg(14-15과) 2박스',
#  '[2박스][산지직송]명품 안동사과 3kg10-15과/중소과 정품 x 2박스',
#  '[자이담][한터] 충주 황금사과 4.5kg (13-18과)',
#  '[정품] 꿀담은 햇 빨간사과 4kg 중과 (17과내외)',
#  '집에서 즐기는 실속 햇 빨간사과 8kg 중대과 (30과내)',
#  '집에서 즐기는 실속 햇 빨간사과 4kg 중소과 (20과내)',
#  '[정품] 꿀담은 햇 빨간사과 3kg 소과 (17과내외)',
#  '[AKmall]경북 부사 사과 10kg 대과 34과내외 (가정용)',
#  '국산 노란 골드 시나노 사과 12과 (3.2kg내외)',
#  '껍질째먹는 미니사과 2kg개당40g이상',
#  '[미미의 밥상][정품] 꿀담은 햇 빨간사과 4kg 대과 (12과내)',
#  '[미미의 밥상][정품] 꿀담은 햇 빨간사과 4kg 중소과 (20과내외)',
#  '[미미의 밥상][정품] 꿀담은 햇 빨간사과 2kg 중소과 (10과내외)',
#  '[미미의 밥상]집에서 즐기는 실속 햇 빨간사과 4kg 중과 (17과내)',
#  '나주배 7.5kg 13-15과 가정용/상품',
#  '[감동][영암신북농협] 신토랑 배 5kg 9-10과 (가정용)',
#  '[감동][영암신북농협] 신토랑 배 5kg 6-8과 (가정용)',
#  '[나주한영배]나주한영배 7.5kg (11-12과)',
#  '껍질째먹는 미니사과 2kg(개당25-3...',
#  '[자연식탁]경북 가정용 빨간사과 8kg 중과(34과내외)',
#  '경북 가정용 빨간사과 4kg 꼬마소과(25~30과내외)',
#  '크기 식감 당도 모두 갖춘 펀치볼 양구 홍로사과 선물세트 상품 5kg',
#  '[AKmall][식품][방씨아들]최상급 나주배 특대 당도 선별 7.5kg(10과수 내',
#  '[자연품애]홍로 세척사과 실중량 5kg 소과',
#  '[산내들]명품 밀양얼음골 사과선물세트 4.5kg(14과)',
#  '새콤달콤 풍부한 과즙 청송 시나노골드 황금사과 10kg 중과',
#  '[웰굿]강원도 홍천 실속형 사과세트 5kg(15-16과)',
#  '달아달아 양광 세척사과 3kg(10-13과) 1박스',
#  '달아달아 시나노 세척사과 4.5kg(16-18과) 2박스',
#  '[산지직송] 껍질째먹는 루비에스 사과 2kg (개당 60g이상)',
#  '[산지직송] 껍질째먹는 루비에스 사과 2kg (개당 50g내외)',
#  '[꿀이구마] 프리미엄 사과 선물세트 5kg 15과 내외',
#  '경북 햇 가정용 부사 4kg중과/17과내외',
#  '[두레]나주배 4.5kg(8~10과_흠집과)',
#  '마음담은 사과 7kg(42~60과_흠집)',
#  '껍질째 먹는 세척사과 2.5kg(9-11과)',
#  '[경북의성] 고당도 햇 사과(대) 3kg/10~12과',
#  '[웰굿]강원도 홍천 실속형 사과세트 총10kg(5kg(20과)x2)',
#  '명절 고급 나주배 선물세트 7.5kg (11-12과)',
#  '[자연품애]바른 가정용 세척사과 실중량 5kg 꼬마소과',
#  '나주농협 신고배 3kg 5과 내외 22년 햇배',
#  '국내산 시나노 골드 사과 12과 (3.2kg내외)',
#  '[현명한농부]영암 신북농협 신고배 5kg (6-8과 가정용) GAP인증',
#  '경북 청송 홍로사과 3kg (10-12과)',
#  '괴산 시나노골드 중소과 3kg 14-16과 황금사과',
#  '[산내들]명품 밀양얼음골 사과선물세트 4.5kg(11과)',
#  '[웰굿] 경북직송 시나노골드 사과 3kg(17과내,가정용소과)',
#  '[웰굿] 경북직송 시나노골드 사과 5kg(18-19과,정품중과)',
#  '아삭아삭한 신선한 가정용 사과 3kg/5kg',
#  '마음담은 사과 3kg(14~15과_흠집)',
#  '마음담은 사과 4kg(19~21과_흠집)',
#  '마음담은 사과 7kg(38~41과_흠집)',
#  '[나주한영배]나주한영배 7.5kg (6-7과)',
#  '[인정한과일] 가정용 알뜰사과 특대과 5kg 10-16과내',
#  '껍질째 먹는 경북 세척사과 3kg 15과내[박스미포함 실중량]',
#  '[자연의선택]명품 사과선물세트 5kg(14-16과)',
#  '[지투지샵]사과 3kg 14-16과',
#  '[지투지샵]사과 5kg 19-22과',
#  '입안가득 시원한 꿀달콤 황금 성환배 4.5kg (11-12과)',
#  '경북 가정용 빨간사과 8kg 소과(46과내외)',
#  '[미인과친한]배 선물세트(600g내외9과)',
#  '경북 가정용 빨간사과 8kg 중소과(40과내외)',
#  '경북 가정용 빨간사과 8kg 꼬마소과(50-60과내외)',
#  '황금사과 시나노골드 소과 5kg 22-24과 프리미엄 노란사과',
#  '[청송팜] 22년 청송 꿀사과 시나노스위트 5kg 17~18과 선물용',
#  '경북 시나노골드 황금사과 5kg 10kg',
#  '[좋은맛닷컴][초록자연] 홍로 햇사과 5kg (14-16과) 선물세트',
#  '당도선별 저탄소 세척사과 3kg (12-16과)',
#  '농협공판장 정성드린 번들 사과 2봉지(봉당5입)',
#  '[찬솔맛나] 경북 상주 아삭달콤 데일리 세척사과 5kg (20~23과)',
#  '[찬솔맛나] 경북 상주 아삭달콤 데일리 세척사과 3kg (11~12과)',
#  '[열매나무] 사과 3kg+3kg 박스당 7~9과내외 (특대과/정품)',
#  '[명가일품][애플팩토리] 알뜰 세척사과 2kg (11과내외/기스,흠과...',
#  '[청송팜] 22년 청송 꿀사과 시나노스위트 5kg 19~20과 선물용',
#  '[노블] 사각 프리미엄 배 선물세트 (5.7kg/배9과)',
#  '[노블] 팔각 VIP 배 선물세트 (7.5kg/배10과)',
#  '바른농부 배 선물세트 1호 (7.5kg/7-10과)',
#  '[초록자연] 홍로 햇사과 5kg (17-19과) 선물용',
#  '햇배 5kg 소과 10~12과',
#  '[현명한농부]영암 신북농협 신고배 5kg (9-10과 가정용) GAP인증',
#  '가정용 맛보장 홍로 사과 중과 5kg 꿀맛 16-18과',
#  '나주 햇 신고배 3kg 가정용/정품',
#  '프리미엄팩 신고배 7.5kg(8-10과) +보자기',
#  '[프레쉬팜]vip 팔각 배 선물세트 7.5kg(배10과)',
#  '프리미엄팩 신고배 7.5kg(13과) +보자기',
#  '[사과랑] 껍질째먹는 세척사과 4kg (23과내) x 2박스',
#  '[나주한영배]나주한영배 단품 5kg (6-7과)',
#  '[착한식탁]바른 가정용 세척사과 실중량 2.5kg 13-18과',
#  '식탐대첩 대추방울토마토 1kg 소과',
#  '[사과꽃필무렵] 사과선물세트 4kg[14~15과]',
#  '경북 문경 시나노골드 5kg 황금사과 /17~18과내외 22년햇사과',
#  '[행복한농부] (1+1)사과배 추석 과일선물세트/사과3kg 배5kg',
#  '[정품] 꿀담은 햇 부사 사과 2kg 중과 (8과내외)',
#  '[정품] 꿀담은 햇 부사 사과 4kg 중소과 (20과내외)',
#  '경북 햇 가정용 부사 4kg대과/12과내외',
#  '[열매나무] 사과 3kg+3kg 박스당 7~9과내외 (특대과/정품)',
#  '22년 나주배 15kg (가정용/20과내)',
#  '경북 가정용 빨간사과 4kg 꼬마소과(25-30과내외)',
#  '경북 가정용 빨간사과 8kg 중과(34과내외)',
#  '[열매나무] 못난이 사과 2kg 8~11과',
#  '경북 알프스오토메 미니사과 2kg 4kg',
#  '크기 식감 당도 모두 갖춘 펀치볼 양구 홍로사과 선물세트 실속 5kg',
#  '나주 프리미엄 햇배 22년 선물용 5kg (5-7과)',
#  '[이푸른] 껍질째 먹는 세척사과 3kg 17과내외 x 2박스',
#  '[이푸른] 사과배 혼합 3호 4kg+4kg (사과13과/배7과 내외)',
#  '크기 식감 당도 모두 갖춘 펀치볼 양구 홍로사과 선물세트 실속 5kg',
#  '[웰굿] 경북직송 시나노골드 사과 2.5kg(12과내,정품중소과)',
#  '새콤달콤 추황배 가정용 5kg',
#  '[이푸른] 껍질째 먹는 세척사과 3kg 17과내외 x 2박스',
#  '[이푸른] 사과배 혼합 3호 4kg+4kg (사과13과/배7과 내외)',
#  '[이푸른] 껍질째 먹는 세척사과 3kg 17과내외',
#  '프리미엄 반건조 서대(2미 220g)10팩 총20미 2.2kg',
#  '경북 청송 홍로사과 선물세트 고급 10kg',
#  '경북 청송 홍로사과 선물세트 일반 5kg',
#  '경북 청송 홍로사과 3kg (13-15과)',
#  '[산지직송] 경북 아삭아삭 사과 2kg (10과내외)',
#  '[산지직송] 경북 아삭아삭 사과 2kg (11-15과내외)',
#  '[자연품애]바른 가정용 세척사과 실중량 5kg 소과',
#  '경북 햇 정품 부사 2kg중소과/10과내외',
#  '[청송팜] 꼬마사과 시나노스위트,홍로 혼합 8kg 46-50과내외',
#  '껍질째먹는 미니사과 2kg개당60g이상',
#  '이츠올릿 경북 시나노 골드 황금 꿀사과 5kg (가정용 꼬마과 25-28과) 노란 스위트 사과 청송 밀양 얼음골',
#  '[미미의 밥상][정품] 꿀담은 햇 빨간사과 2kg 중과 (8과내외)',
#  '가을맛 홍로햇사과 빨간사과 가정용 중대과 5kg',
#  '[자연예서] 홍로 햇사과 10kg (30과 내외) 선물용',
#  '지리산 고랭지 홍로 꿀 사과 부사 고당도 GAP 고급 선물용 가정용 4kg 5kg',
#  '달아달아 양광 세척사과 3kg(14-15과) 2박스',
#  '달아달아 양광 세척사과 4.5kg(17-20과) 1박스',
#  '집에서 즐기는 실속 햇 부사 사과 8kg 중과 (34과내외)',
#  '달아달아 시나노 세척사과 3kg(8-10과) 1박스',
#  '가정용흠집 홍로사과 중소과 19-21과 5kg',
#  '경북 가정용 빨간사과 4kg 사이즈별',
#  '이츠올릿 경북 햇 홍로 부사 꿀 사과 5kg 정품 중소과 (19-21과) 껍질째 먹는 가정용 청송 안동 문경 장수',
#  '집에서 즐기는 실속 햇 부사 사과 4kg 중소과 (20과내외)',
#  '[착한식탁]바른 가정용 세척사과 실중량 2.5kg 12-14과',
#  '[열매나무] 사과 3kg 7~9과내외 ( 특대과 / 정품)',
#  '과즙짱 못난이 상주배 5kg (8~12과)',
#  '신선하고 달콤한 경북 사과 3kg 11-13과내외',
#  '[팜쿡] 무진장 맛있는 경북 홍로 가정용 대 10kg',
#  '[한터] 충주 황금사과 4.5kg(13-18과)',
#  '나주배 선물용 선물세트 고당도 햇배 5kg 7.5kg',
#  '[AKmall][식품][프레시팜] 가을담음 햇 사과,배 선물세트 2.8kg',
#  '시나노골드 가정용 중과 5kg 22-24과 황금사과',
#  '나주 신고배 선물세트 5kg(6-8과)',
#  '아삭 달콤한 배 정품 2kg/3kg/4kg',
#  ...]

# %%
names = driver.find_elements_by_class_name('srchProductUnitTitle')

# %%
for nas in range(0,len(names)):
    print(names[nas].text)

# %%
names = driver.find_elements_by_css_selector('.srchProductUnitInfoArea .srchProductInfoColumn .srchProductUnitTitle')
dldl = []
for namean in range(0,len(names)):
    dldl.append(names[namean].text)

# %%
len(names)
# Out:
# 60

# %%
dldl
# Out:
# ['충주 GAP 상생사과 (2.5KG/봉)',
#  '22년 산지직송 햇 나주배 가정용/가정용특품 3kg 5kg 15kg',
#  '홍로 사과 (4-7입/봉)',
#  '황금빛 김천 황옥 사과 (1.3KG/봉)',
#  '상생 배 (3KG/박스)',
#  '[GAP인증] 22년 고당도 햇 나주배 가정용/특품 3kg 5kg 15kg 나주직송 꼼꼼선별배송',
#  '정품 홍옥 사과 2kg내외',
#  '작아도 맛있는 밀양얼음골 사과 (6-10입/봉)',
#  '[2022햇사과] 산지애 씻어나온 꿀사과 3kg 2box (대과)',
#  '아리수 사과 (4-7입/봉)',
#  '세척사과 10kg 33-50과',
#  '문경사과 감홍사과 꿀 햇 산지직송사과 5kg 10kg',
#  '맘사과 가정용 사과 10Kg 대과(20~27과)',
#  '아삭아삭 시원한 달콤 당도선별 정품 햇배 중과 10kg',
#  '당도선별 아삭아삭 빨간 홍로사과 가정용 중과 5kg',
#  '22년산 햇배 나주 신고배 3kg 5kg 산지직송',
#  '세척사과 실중량 3kg+3kg(20~30과)',
#  '[산지직송] 정성들여 키운 달콤한 나주 신고배 5kg (9-10과)',
#  '꿀 홍로 햇사과 5kg 10kg 껍질째먹는 고당도 게르마늄 사과',
#  '[제] 사과 4-8입/봉 (슈퍼)',
#  '22년 울산 서생배 신고배 정품배 5kg 7.5kg 10kg 15kg',
#  '영천 루비에스 미니사과 (10-16입/팩)',
#  '황금 사과 시나노골드 노란 못난이 3kg 5kg 청송 산지직송 가정용',
#  '세척사과 실중량 3kg+3kg+3kg(30~45과)',
#  '맘사과 가정용 사과 5Kg 대과(10~13과)',
#  '나씨네 문경 감홍 사과 3 4 5 10 kg 제철 과일 선물 사과 1021662',
#  '[정품] 꿀담은 햇 시나노골드 사과 3kg / 4kg 옵션 선택',
#  '사과 세척사과 3kg+3kg(20-30과)',
#  '[햇살가득] 경북 가정용 햇 사과 3.5kg (20~24과)',
#  '[베리세상] 국내산 대추사과 1kg (대)',
#  '아삭달콤 꿀 사과 4kg / 2개 주문시 10kg발송',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 9kg 소과 (50-65과)',
#  '[싱싱유통]2022수확 가정용 홍로 사과 7kg 중대과',
#  '[산지직송] 의성 황금사과(시나노골드) 중 4kg',
#  '경북 의성 햇 홍옥 사과 GAP 경북사과 5kg',
#  '열매나무 못난이 사과 3kgX3박스',
#  '세척사과 3kg+3kg+3kg(30-45과)',
#  '[대한농산] 정품 홍옥 사과 2kg내외(12과내외)',
#  '[착한식탁] 바른 가정용 세척사과 실중량 2.5kg 13-18과',
#  '맘사과 가정용 사과 10Kg 갈아먹는사과',
#  '경북 홍로 사과 가정용 5kg 29-33과',
#  '[방씨아들]경북 부사사과 고당도 꿀사과 3kg',
#  '[사전예약 10/12(수) 순차출고] 문경 고당도 감홍사과 3kg 10과내',
#  '사과 햇 홍로 청송 껍질째먹는 가을 꿀 사과 5kg',
#  '달빛사과 양광 세척사과 꿀사과 햇사과 4.5kg 21~23과',
#  '[2022햇사과] 산지애 알뜰 못난이사과(소과) 4.5kg 2box',
#  '[산지애] [빠른배송]NFC 사과즙 사과주스 사과원액 사과 120ml 60팩',
#  '아침이슬사과 경북 가정용 꿀사과 22년 햇 가을사과 9kg 대과 (29과내)',
#  '달빛사과 양광 세척사과 꿀사과 햇사과 3kg 10~13과',
#  '껍질째먹는 세척사과 5kg (23과내)',
#  '한입 꼬마사과 5kg 27~33과 (가정용)',
#  '시나노골드 가정용 대과 5kg 10-12과 황금사과',
#  '맘사과 가정용 사과 10Kg 대중과(28~33과)',
#  '[싱싱유통]홍로 세척사과 실중량 2.5kg (13-18과 내외) 꼬마소과',
#  '농가돕기사과(5~11입/봉)',
#  '옥이네청과 주스용 사과 10kg 가정용 못난이 기스 흠과 (부자재포함중량)',
#  '[대한농산] 정품 홍옥 사과 2kg내외(8과내외)',
#  '[싱싱유통]세척 아오리사과 5kg 꼬마소과 18-28과내외',
#  '달아달아 시나노 스위트 사과 4.5kg(13-15과) 1박스',
#  '[AKmall][식품][방씨아들]꿀 경북 청송 햇 사과 부사사과 못난이사과(']

# %%
def first_category():
    # 카테고리 항목 가져오기 # 대분류 # 식품 
    product = driver.find_elements_by_css_selector(' .srchFilterAccordionPanel .srchFilterOptions')
    product_list = str(product[0].text).split('\n')[:]
    
    return category_add()
def category_add():
    while True:
        time.sleep(1)
        try:
            for i in range(1,len(product_list)):
                # 식품 카테고리 순서대로 들어가기 # 중분류로 들어감 
                driver.find_element_by_xpath(f'//*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/ul/li[{i}]/a/span').click()
                time.sleep(2)
                # 해당 카테고리 항목 가져오기 # 중분류 카테고리 가져옴 Ex) 과일(사과/배)등 
                # 전부를 가져오지 않고 하나하나 가지고 와야 하나.. 둘..
                product_2 = driver.find_elements_by_css_selector(' .srchFilterAccordionPanel .srchFilterOptions')
                product_2_list = str(product_2[0].text).split('\n')[:]
                    # 이 밑 부분 반복
                    # 소분류 카테고리로 진입 Ex) 사과/배 상품
                    driver.find_element_by_xpath(f'//*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/ul/li[{i}]/a/span').click()
                    # 소분류 카테고리 속 상품명 가져옴
                    driver.find_elements_by_css_selector('.srchProductInfoColumn .srchProductUnitTitle')
                    # 다음 버튼 클릭 (끝까지 반복) # 사과/배 같은 경우 35페이지
                    # 페이지 끝까지 가서 상품 명을 다 가지고 왔을 경우 뒤로가기 클릭 
                    # 그 후 다른 카테고리로 진입 
                driver.find_element_by_xpath('//*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/div/a').click()

        except Exception as e:
            print(e)
            break

# %%
a = first_category()

# %%
a

# %%
fruit = driver.find_elements_by_css_selector('#content > div > section > div.srchResultArea > section.srchFilterArea > ul.srchFilterAccordion > li:nth-child(2) > div > ul')
for i in range(0, len(fruit)):
    print(fruit[i].text)
# Out:
# 과일
# 채소
# 쌀/잡곡/견과
# 수산/건어물
# 정육/계란
# 우유/유제품
# 냉장/냉동/간편식
# 김치/반찬
# 생수/음료/주류
# 커피/원두/차
# 과자/디저트/아이스크림
# 면류/통조림
# 소스/오일/장류
# 건강/다이어트식품

# %%
#content > div > section > div.srchResultArea > section.srchFilterArea > ul.srchFilterAccordion > li:nth-child(2) > div > ul
#content > div > section > div.srchResultArea > section.srchFilterArea > ul.srchFilterAccordion > li:nth-child(2) > div > ul
#content > div > section > div.srchResultArea > section.srchFilterArea > ul.srchFilterAccordion > li:nth-child(2) > div > ul

//*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/ul/li[1]/a/span
//*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/ul/li[{i}]/a/span

# %%
a = driver.find_elements_by_css_selector('.srchProductInfoColumn .srchProductUnitTitle')

# %%
for w in range(1,len(a)):
    print(a[w].text)
# Out:
# [본사직영]석류 콜라겐 젤리스틱 6박스 /저분자콜라겐 1200mg함유
# [본사직영]프로메가 알티지 오메가3 듀얼 5박스(5개월분) 장용성캡슐
# [장용성리뉴얼]프로메가 기억력 오메가3 트리플 6박스(6개월분) 혈행+눈건조+기억력
# [본사직영]아이클리어 루테인지아잔틴 6박스(6개월분)
# [대용량 출시]아이클리어 루테인 키즈 200포 1박스(100일분) 포도맛젤리 루테인
# (3+1) 낭만부부 모짜렐라 치즈가래떡 500g 3봉 구매시 1봉 추가 증정
# (본사직영) 아이시스8.0 생수 200ml/300ml/500ml/2L 외 모음
# Only Price 1등급 우유 (930ML*2입)
# (본사직영)코크제로 355ml캔 24입
# (본사직영) 제주 삼다수 그린 무라벨 500ml 40병 (유라벨 랜덤발송)
# 완도활전복 13-14미 1kg [평일3시주문-당일발송]
# 제주 햇 감귤 로열과4.5kg 外
# 해태htb 영진 구론산 탄산 오리지날 150ml 30개
# (본사직영)코카콜라 300PET 24입
# (본사직영) 제주 삼다수 그린 무라벨 500ml 20병 (유라벨 랜덤발송)
# [허닭] 무료배송 곤약볶음밥/맛있는볶음밥 250g 1팩
# 해태htb 강원평창수 무라벨 2.0PET 12입
# Only Price 미네랄워터ECO (2L*6입)
# 제주 삼다수 그린 (2L*6입)
# (본사직영) 토레타 500ml PET 24입
# (본사직영) 제주 삼다수 2L 12병 [유/무라벨 랜덤발송]
# O [본사직영] 비타민C 1000 600정
# 빅토리아 탄산수/탄산음료 500ml x 40페트 8종 택2
# 통통한 통살 먹태 4+1마리 기획
# 닭가슴살 곤약 볶음밥/식단 맛있는 볶음밥 1팩
# 이클립스x8개 (페퍼민트/스피어민트/스트로베리/피치)
# 행복생생란(대란, 30입) (1.56KG)
# (본사직영) 제주 삼다수 그린 무라벨 2L 12병 [재고 부족시 유라벨 발송]
# 노르웨이 생연어 300g 500g 1kg 통살 연어회 필렛 스테이크
# 닥터린 알티지(rTG) 오메가3 (12개월분/12박스)
# 제주 삼다수 그린 (500ML*20입)
# 해태htb 조지아맥스 240ml캔 30개
# (본사직영)코크제로 300PET 24입
# (본사직영) 제주 삼다수 그린 무라벨 500ml 60병 (유라벨 랜덤발송)
# 해태htb 영진 구론산 오리지날 150ml 30개
# 당근 (100G)
# 흰다리새우 (마리)
# (본사직영) 아이시스8.0 에코 생수 2.0L 24펫
# 대상웰라이프 뉴케어 당플랜 200ml x 30팩
# (본사직영) 토레타 900mlPET 12입
# (본사직영) 제주 삼다수 2L 6병 [유/무라벨 랜덤발송]
# 해태htb 스프라이트킨사이다 355ml 24입
# 고소 담백 베이컨 1kg 파지 뭉치형 / 슬라이스 20cm
# 사세 순살치킨 가라게 1kg
# 해태htb 썬키스트 훼미리 제주감귤농장 2.0L 6개
# Only Price 미네랄워터ECO (500ML*20입)
# Sweet Hug 코인초콜릿 해피 할로윈 (100G)
# 이종임의 쫄깃스지 진한 도가니탕 10팩
# Only Price 스파클링 사이다 (레몬향) (1.5L)
# 예소담 특포기김치 8kg
# 국내산 애호박 (개)
# 호주산 곡물비육 척아이롤(스테이크용) (100G)
# 어깨동무 알찬콩 콩나물 (300G)
# 국내산 돼지 삼겹살 구이용(냉장) (100G)
# 어깨동무 알찬콩 두부 (300G)
# 국내산 돼지 앞다리 불고기용(냉장) (100G)
# (본사직영) 파워에이드 MB 600mlPET 20입
# B750 바나나 (900G 내외)
# 펩시콜라 제로슈거 (245ML*8캔)

# %%
과일 - //*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/ul/li[16]/a
채소 - //*[@id="content"]/div/section/div[1]/section[2]/ul[2]/li[2]/div/ul/li[15]/a
